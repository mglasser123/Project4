# %%
# Dependencies
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")

# File to Load 
customer_data_to_load = Path("Resources/customer_churn.csv")

# Read Data File and store into Pandas DataFrames
churn_df = pd.read_csv(customer_data_to_load)

# View the dataset
churn_df.head()
# Out:
#               Names  Age  Total_Purchase  Account_Manager  Years  Num_Sites  \
# 0  Cameron Williams   42        11066.80                0   7.22          8
# 1     Kevin Mueller   41        11916.22                0   6.50         11
# 2       Eric Lozano   38        12884.75                0   6.67         12
# 3     Phillip White   42         8010.76                0   6.71         10
# 4    Cynthia Norton   37         9191.58                0   5.56          9
#
#       Onboard_date                                           Location  \
# 0   8/30/2013 7:00      10265 Elizabeth Mission Barkerburgh, AK 89518
# 1   8/13/2013 0:38  6157 Frank Gardens Suite 019 Carloshaven, RI 1...
# 2   6/29/2016 6:20             1331 Keith Court Alyssahaven, DE 90114
# 3  4/22/2014 12:43       13120 Daniel Mount Angelabury, WY 30645-4695
# 4  1/19/2016 15:31                765 Tricia Row Karenshire, MH 71730
#
#                        Company  Churn
# 0                   Harvey LLC      1
# 1                   Wilson PLC      1
# 2  Miller, Johnson and Wallace      1
# 3                    Smith Inc      1
# 4                   Love-Jones      1

# %%
# Changing column names to make data cleaner
churn_df = churn_df.rename(columns = {'Total_Purchase': 'Total Purchase', 'Account_Manager' : 'Account Manager', 'Num_Sites': 'Number of Websites Used', 'Onboard_date' : 'Onboard Date'})

# View updated column names
churn_df.head()
# Out:
#               Names  Age  Total Purchase  Account Manager  Years  \
# 0  Cameron Williams   42        11066.80                0   7.22
# 1     Kevin Mueller   41        11916.22                0   6.50
# 2       Eric Lozano   38        12884.75                0   6.67
# 3     Phillip White   42         8010.76                0   6.71
# 4    Cynthia Norton   37         9191.58                0   5.56
#
#    Number of Websites Used     Onboard Date  \
# 0                        8   8/30/2013 7:00
# 1                       11   8/13/2013 0:38
# 2                       12   6/29/2016 6:20
# 3                       10  4/22/2014 12:43
# 4                        9  1/19/2016 15:31
#
#                                             Location  \
# 0      10265 Elizabeth Mission Barkerburgh, AK 89518
# 1  6157 Frank Gardens Suite 019 Carloshaven, RI 1...
# 2             1331 Keith Court Alyssahaven, DE 90114
# 3       13120 Daniel Mount Angelabury, WY 30645-4695
# 4                765 Tricia Row Karenshire, MH 71730
#
#                        Company  Churn
# 0                   Harvey LLC      1
# 1                   Wilson PLC      1
# 2  Miller, Johnson and Wallace      1
# 3                    Smith Inc      1
# 4                   Love-Jones      1

# %%
# Summarize the data
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Names                    900 non-null    object
#  1   Age                      900 non-null    int64
#  2   Total Purchase           900 non-null    float64
#  3   Account Manager          900 non-null    int64
#  4   Years                    900 non-null    float64
#  5   Number of Websites Used  900 non-null    int64
#  6   Onboard Date             900 non-null    object
#  7   Location                 900 non-null    object
#  8   Company                  900 non-null    object
#  9   Churn                    900 non-null    int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 70.4+ KB

# %%
# Drop the non-beneficial ID columns.
churn_df = churn_df.drop(["Names","Onboard Date","Location","Company"],1)
churn_df.head()
# Out:
#    Age  Total Purchase  Account Manager  Years  Number of Websites Used  Churn
# 0   42        11066.80                0   7.22                        8      1
# 1   41        11916.22                0   6.50                       11      1
# 2   38        12884.75                0   6.67                       12      1
# 3   42         8010.76                0   6.71                       10      1
# 4   37         9191.58                0   5.56                        9      1

# %%
# Determine the number of unique values in each column.
churn_df.nunique()
# Out:
# Age                         36
# Total Purchase             900
# Account Manager              2
# Years                      418
# Number of Websites Used     12
# Churn                        2
# dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
y = churn_df['Churn'].values

# Separate the X variable, the features
x = churn_df.drop(columns='Churn').values

# Split the preprocessed data into a training and testing dataset
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
x_scaler = scaler.fit(x_train)

# Scale the data
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(x_train[0])
hidden_nodes_layer1 =  200
hidden_nodes_layer2 = 100

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 200)               1200
#
#  dense_1 (Dense)             (None, 100)               20100
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 21401 (83.60 KB)
# Trainable params: 21401 (83.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(x_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 1s 3ms/step - loss: 0.4424 - accuracy: 0.8356
# Epoch 2/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2955 - accuracy: 0.8859
# Epoch 3/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2591 - accuracy: 0.8978
# Epoch 4/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2510 - accuracy: 0.8993
# Epoch 5/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2462 - accuracy: 0.8948
# Epoch 6/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2404 - accuracy: 0.9067
# Epoch 7/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2393 - accuracy: 0.9037
# Epoch 8/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2333 - accuracy: 0.9052
# Epoch 9/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2303 - accuracy: 0.9037
# Epoch 10/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2258 - accuracy: 0.9052
# Epoch 11/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2259 - accuracy: 0.9096
# Epoch 12/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2271 - accuracy: 0.9052
# Epoch 13/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2228 - accuracy: 0.9037
# Epoch 14/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2205 - accuracy: 0.9081
# Epoch 15/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2222 - accuracy: 0.9067
# Epoch 16/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2190 - accuracy: 0.9111
# Epoch 17/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2236 - accuracy: 0.9081
# Epoch 18/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2148 - accuracy: 0.9111
# Epoch 19/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2153 - accuracy: 0.9111
# Epoch 20/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2095 - accuracy: 0.9111
# Epoch 21/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2108 - accuracy: 0.9096
# Epoch 22/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2174 - accuracy: 0.9096
# Epoch 23/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2080 - accuracy: 0.9111
# Epoch 24/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2057 - accuracy: 0.9170
# Epoch 25/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2060 - accuracy: 0.9141
# Epoch 26/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2030 - accuracy: 0.9230
# Epoch 27/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2009 - accuracy: 0.9111
# Epoch 28/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2009 - accuracy: 0.9141
# Epoch 29/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2003 - accuracy: 0.9230
# Epoch 30/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2016 - accuracy: 0.9126
# Epoch 31/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1971 - accuracy: 0.9156
# Epoch 32/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1988 - accuracy: 0.9126
# Epoch 33/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1971 - accuracy: 0.9230
# Epoch 34/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1961 - accuracy: 0.9170
# Epoch 35/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1942 - accuracy: 0.9170
# Epoch 36/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1928 - accuracy: 0.9215
# Epoch 37/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1988 - accuracy: 0.9126
# Epoch 38/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1946 - accuracy: 0.9289
# Epoch 39/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1967 - accuracy: 0.9170
# Epoch 40/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1870 - accuracy: 0.9230
# Epoch 41/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1918 - accuracy: 0.9200
# Epoch 42/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1945 - accuracy: 0.9230
# Epoch 43/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1876 - accuracy: 0.9215
# Epoch 44/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1847 - accuracy: 0.9215
# Epoch 45/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1827 - accuracy: 0.9274
# Epoch 46/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1812 - accuracy: 0.9230
# Epoch 47/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1779 - accuracy: 0.9259
# Epoch 48/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1800 - accuracy: 0.9215
# Epoch 49/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1783 - accuracy: 0.9215
# Epoch 50/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1787 - accuracy: 0.9230
# Epoch 51/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1786 - accuracy: 0.9289
# Epoch 52/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1818 - accuracy: 0.9215
# Epoch 53/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1899 - accuracy: 0.9215
# Epoch 54/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1872 - accuracy: 0.9304
# Epoch 55/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1759 - accuracy: 0.9230
# Epoch 56/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1741 - accuracy: 0.9274
# Epoch 57/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1705 - accuracy: 0.9289
# Epoch 58/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1691 - accuracy: 0.9274
# Epoch 59/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1686 - accuracy: 0.9304
# Epoch 60/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1786 - accuracy: 0.9215
# Epoch 61/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1699 - accuracy: 0.9319
# Epoch 62/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1684 - accuracy: 0.9274
# Epoch 63/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1672 - accuracy: 0.9274
# Epoch 64/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1632 - accuracy: 0.9304
# Epoch 65/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1778 - accuracy: 0.9378
# Epoch 66/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1719 - accuracy: 0.9215
# Epoch 67/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1825 - accuracy: 0.9230
# Epoch 68/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1698 - accuracy: 0.9259
# Epoch 69/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1621 - accuracy: 0.9304
# Epoch 70/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1581 - accuracy: 0.9348
# Epoch 71/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1605 - accuracy: 0.9274
# Epoch 72/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1628 - accuracy: 0.9319
# Epoch 73/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1656 - accuracy: 0.9304
# Epoch 74/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1609 - accuracy: 0.9289
# Epoch 75/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1589 - accuracy: 0.9319
# Epoch 76/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1557 - accuracy: 0.9333
# Epoch 77/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1529 - accuracy: 0.9393
# Epoch 78/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1505 - accuracy: 0.9378
# Epoch 79/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1461 - accuracy: 0.9496
# Epoch 80/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1516 - accuracy: 0.9348
# Epoch 81/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9304
# Epoch 82/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1464 - accuracy: 0.9437
# Epoch 83/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1859 - accuracy: 0.9200
# Epoch 84/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1481 - accuracy: 0.9393
# Epoch 85/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1452 - accuracy: 0.9422
# Epoch 86/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1463 - accuracy: 0.9378
# Epoch 87/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1443 - accuracy: 0.9348
# Epoch 88/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1406 - accuracy: 0.9467
# Epoch 89/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1369 - accuracy: 0.9467
# Epoch 90/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1358 - accuracy: 0.9393
# Epoch 91/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1527 - accuracy: 0.9304
# Epoch 92/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1368 - accuracy: 0.9378
# Epoch 93/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1363 - accuracy: 0.9363
# Epoch 94/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1345 - accuracy: 0.9496
# Epoch 95/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1301 - accuracy: 0.9467
# Epoch 96/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1368 - accuracy: 0.9348
# Epoch 97/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1322 - accuracy: 0.9481
# Epoch 98/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1416 - accuracy: 0.9289
# Epoch 99/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1333 - accuracy: 0.9437
# Epoch 100/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1308 - accuracy: 0.9407

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.5042 - accuracy: 0.8578 - 182ms/epoch - 23ms/step
# Loss: 0.5042040348052979, Accuracy: 0.8577777743339539

# %%
# Export our model to HDF5 file
nn.save('Churn.h5')
